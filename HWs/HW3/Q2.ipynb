# %% [markdown]
# # Q2

# %% [markdown]
# *   In this question we will Build a bigram HMM tagger.
# *   First we split the part-of-speech-tagged corpus into a training set and test set.
# *   From the labeled training set, we train the transition and observation probabilities of the HMM tagger directly on the hand-tagged data.
# *   Then implement the Viterbi algorithm so we can decode a test sentence.
# *   Run the algorithm on the test set. Report its error rate and
# compare its performance to the most frequent tag baseline.
# *   Build a confusion matrix and investigate the most frequent errors.

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# True

# %%
import math
import nltk
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.

# %%
def collect_probabilities(_samples):
    """
    Collects various probabilities and frequencies required for Hidden Markov Model (HMM) training based on given samples.

    Args:
    _samples (list): A list of tuples containing (word, tag)=(x, y) pairs representing training data.

    Returns:
    tuple: A tuple containing four dictionaries:
           - tag_freq: A dictionary storing the frequency of each tag type. (counts for normalizing)
           - word_per_tag_freq: A nested dictionary storing the frequency of each word under each tag. (B observation likelihoods)
           - bigram: A nested dictionary representing the bigram probabilities between tag types. (A transition probabilities)
           - pi: A dictionary storing the initial probability distributions for tag types. (initial probabilities)

    Comments:
    - tag_freq: Stores the frequency of each tag type observed in the training data.
    - word_per_tag_freq: Stores the frequency of each word observed under each tag in the training data.
      - Each word under a specific tag is initialized with a count of 2 to provide initial smoothing.
    - bigram: Represents the transition probabilities between tag types based on bigram counts.
    - pi: Stores the initial probability distributions for tag types based on the second tag in each sample.
    """
    tag_freq = {}
    word_per_tag_freq = {}
    bigram = {}
    pi = {}
    samples_len = len(_samples)

    # Iterate through samples to collect tag frequencies, word frequencies under each tag, and initial probabilities
    for i in range(samples_len):
        sample = _samples[i] # sample=(word, tag)=(x, y)
        has_next = i + 1 < samples_len

        # Collect data for initial probabilities (pi)
        if has_next:
            if _samples[i + 1][1] not in pi:
                pi.update({_samples[i + 1][1]: 2}) # 2: 1+1 laplace smoothing
            else:
                # Your code here
                pi[_samples[i + 1][1]] += 1

        # Count tag frequencies (tag_freq) and word frequencies under each tag (word_per_tag_freq)
        if sample[1] not in tag_freq: # sample=(word, tag)=(x, y)
            tag_freq.update({sample[1]: 2})
            word_per_tag_freq.update({sample[1]: {sample[0]: 2}})
        else:
            # Your code here
            tag_freq[sample[1]] += 1
            if sample[0] not in word_per_tag_freq[sample[1]]:
                word_per_tag_freq[sample[1]].update({sample[0]: 2})
                # word_per_tag_freq[sample[1]][sample[0]] = 2
            else:
                word_per_tag_freq[sample[1]][sample[0]] += 1


    # Initialize the bigram matrix with default counts
    for tag_0 in tag_freq:
        bigram.update({tag_0: {}})
        for tag_1 in tag_freq:
            bigram[tag_0].update({tag_1: 1})

    # Count bigram occurrences
    for i in range(samples_len):
        # Your code here
        if i > 0:
            prev_tag = _samples[i - 1][1]  # sample=(word, tag)=(x, y)
            current_tag = _samples[i][1]
            bigram[prev_tag][current_tag] += 1 # bigram(NN, VB) += 1

    # # Convert counts to probabilities
    # for tag_0 in bigram:
    #     total_count = sum(bigram[tag_0].values())
    #     for tag_1 in bigram[tag_0]:
    #         bigram[tag_0][tag_1] /= total_count

    # # Normalize initial probabilities (pi)
    # total_init_count = sum(pi.values())
    # for tag in pi:
    #     pi[tag] /= total_init_count

    # Return collected probabilities and frequencies
    return tag_freq, word_per_tag_freq, bigram, pi

# %%
def create_confusion_matrix(predictions, hidden_state, confusion_matrices , is_correct):
    """
    Updates the confusion matrices based on the predictions and hidden states,
    calculates the number of correct predictions, and identifies tags with
    the most false positives and false negatives.

    Args:
    predictions (list): Predicted sequence of tags for the given input data.
    hidden_state (list): Actual sequence of tags for the given input data.
    confusion_matrices (dict): A dictionary containing confusion matrices for each tag.
    is_correct (int): Counter for the number of correct predictions.

    Returns:
    int: Updated count of correct predictions after processing the input data.

    Comments:
    - As the Viterbi algorithm processes each sentence in the test data,
      it compares the predicted tags against the actual tags for each word in the sentence.
        - For each word in the sentence, if the predicted tag matches the actual tag (a true positive),
          the corresponding count in the confusion matrix for that tag is incremented.
        - If the predicted tag does not match the actual tag:
            - If the predicted tag is incorrect (a false positive), the FP count for
              the predicted tag is incremented, and the TN counts for other tags are incremented.
            - If the actual tag is not predicted (a false negative), the FN count for the actual
              tag is incremented, and the TN counts for other tags are incremented.
    - After updating the confusion matrices, the function identifies tags with
      the highest counts of false positives and false negatives.
    """
    # fill in the confusion matrix
    for i in range(len(predictions)):
        if predictions[i] == hidden_state[i]:
            # prediction is correct
            is_correct += 1
            for tag in confusion_matrices:
                if predictions[i] == tag:
                    confusion_matrices[tag]['TP'] += 1 # model truly said positive
                else:
                    confusion_matrices[tag]['TN'] += 1 # model truly said negative
        else:
            # prediction is incorrect
            for tag in confusion_matrices:
                if predictions[i] == tag: # If the predicted tag is incorrect
                    confusion_matrices[tag]['FP'] += 1 # model falsely said positive
                elif hidden_state[i] == tag: # If the actual tag is not predicted
                    confusion_matrices[tag]['FN'] += 1 # model falsely said negative
                else:
                    confusion_matrices[tag]['TN'] += 1 # model truly said negative


    # rank
    highest_FP_tag = []
    highest_FP = -1
    highest_FN_tag = []
    highest_FN = -1

    for tag in confusion_matrices:

        print(f'{tag}: {confusion_matrices[tag]}')

        if confusion_matrices[tag]['FP'] > highest_FP:
            highest_FP = confusion_matrices[tag]['FP']
            highest_FP_tag = tag

        if confusion_matrices[tag]['FN'] > highest_FN:
            highest_FN = confusion_matrices[tag]['FN']
            highest_FN_tag = tag

    print(f'\nTag with the most false positives is: {highest_FP_tag} with {highest_FP} counts.')
    print(f'Tag with the most false negative is:  {highest_FN_tag} with {highest_FN} counts.')

    return is_correct

# %%
def viterbi(_samples, _tag_freq, _word_per_tag_freq, _bigram, _init_dist):
    """
    Performs the Viterbi algorithm for part-of-speech tagging on a given test set of sentences.

    Args:
    _samples (list): A list of tuples containing (word, tag)=(x, y) pairs representing the test data.
    _tag_freq (dict): A dictionary storing the frequency of each tag type observed in the training data.
    _word_per_tag_freq (dict): A nested dictionary storing the frequency of each word observed under each tag in the training data.
    _bigram (dict): A nested dictionary representing the bigram probabilities between tag types.
    _init_dist (dict): A dictionary storing the initial probability distributions for tag types.

    Comments:
    - This function implements the Viterbi algorithm for part-of-speech tagging.
    - It processes each sentence in the test set, using '.' as an indicator that a sentence is over.
    - The function populates a confusion matrix to track the performance of the model.
    - The Viterbi algorithm is used to find the most likely sequence of tags for each sentence.
    - The algorithm iterates through each word in the sentence, calculating the most likely tag sequence based on probabilities and transition probabilities.
    - The model's predictions are compared against the actual tags to evaluate accuracy and populate the confusion matrix.
    - The function prints detailed information about predictions, including the sentence, hidden states, and predicted tags.
    - It also identifies tags with the most false positives and false negatives based on the confusion matrix.
    - Finally, the function prints the overall accuracy of the model on the test set.
    """
    test_size = len(_samples)
    current_index = 0
    is_correct = 0

    # populate the confusion matrix
    confusion_matrices = {}
    for tag in _tag_freq:
        confusion_matrices.update({tag: {'TP': 0, 'FP': 0, 'TN': 0, 'FN': 0}})

    while current_index < test_size:
        # find the boundry of a sentence
        sentence = []
        hidden_state = []
        last_token = ''
        while last_token != '.' and current_index < test_size:
            sentence.append(_samples[current_index][0]) # _samples[current_index]=(word, tag)=(x, y)
            hidden_state.append(_samples[current_index][1])
            last_token = sentence[-1]
            current_index += 1

        # initialization step
        path_probability = {}
        backpointer = {}
        for tag in init_dist:
            path_probability.update({tag: []})
            backpointer.update({tag: [0]})

            # initial distribution of this tag
            pi_tag = init_dist[tag]

            # b_word is the probability of the word being generated by this tag
            if sentence[0] in _word_per_tag_freq[tag]:
                b_word = _word_per_tag_freq[tag][sentence[0]] / _tag_freq[tag]
            else:
                b_word = 2.2250738585072014e-100 # epsilon
            path_probability[tag].append(pi_tag * b_word)
            # path_probability[tag][0] = math.log(pi_tag * b_word, 10)

        # recursion step
        T = len(sentence)
        for i in range(1, T):
            for tag in init_dist:

                if sentence[i] in _word_per_tag_freq[tag]:
                    b_word = _word_per_tag_freq[tag][sentence[i]] / _tag_freq[tag]
                else:
                    b_word = 2.2250738585072014e-100

                # search the maximum value of
                # viterbi[s', t-1] * a(s|s') * b_s(o_t)
                best_trans_prob = -2.2250738585072014e+308 
                best_trans_tag = ''
                for prev_tag in init_dist:
                    if prev_tag in _bigram and tag in _bigram[prev_tag]:
                        transitional_prob = _bigram[prev_tag][tag] / _tag_freq[prev_tag]
                    else:
                        transitional_prob = 2.2250738585072014e-100

                    prob = path_probability[prev_tag][i - 1] + math.log(transitional_prob * b_word, 10)

                    if prob > best_trans_prob:
                        best_trans_prob = prob
                        best_trans_tag = prev_tag

                path_probability[tag].append(best_trans_prob)
                backpointer[tag].append(best_trans_tag)

        # termination step
        best_path_prob = -2.2250738585072014e+308
        best_path_pointer = None
        for tag in init_dist:
            # Your code here
            if path_probability[tag][-1] > best_path_prob:
            # if path_probability[tag][T-1] > best_path_prob:
                best_path_prob = path_probability[tag][-1]
                best_path_pointer = tag

        predictions = [best_path_pointer]

        # make the predictions path
        for i in reversed(range(1, T)):
            # Your code here
            # predictions.append(backpointer[predictions[-1]][i])
            best_path_pointer = backpointer[best_path_pointer][i]
            predictions.append(best_path_pointer)

        predictions.reverse()

        print(f'sentence:       {sentence}')
        print(f'hidden s:       {hidden_state}')
        print(f'predictions:    {predictions}')

        is_correct = create_confusion_matrix(predictions, hidden_state, confusion_matrices, is_correct)

    print(f'\nmodel got {is_correct} samples correct out of {test_size}')
    print(f'accuracy: {is_correct / test_size}')

# %%
CORPUS = brown.tagged_words(categories='news', tagset='universal')
CORPUS_SIZE = len(brown.tagged_words(categories='news'))

CUT_OFF = math.floor(CORPUS_SIZE * 0.75)

# section off training and testing lists from corpus
training_list = CORPUS[:CUT_OFF]
testing_list = CORPUS[CUT_OFF:]

tag_frequency, word_per_tag_frequency, tag_bigram, init_dist = collect_probabilities(training_list)
viterbi(testing_list, tag_frequency, word_per_tag_frequency, tag_bigram, init_dist)
# Out:
# Streaming output truncated to the last 5000 lines.
# ADP: {'TP': 2248, 'FP': 221, 'TN': 16203, 'FN': 87}
# .: {'TP': 2272, 'FP': 51, 'TN': 16436, 'FN': 0}
# ADV: {'TP': 656, 'FP': 64, 'TN': 17862, 'FN': 177}
# CONJ: {'TP': 565, 'FP': 4, 'TN': 18183, 'FN': 7}
# PRT: {'TP': 420, 'FP': 40, 'TN': 18231, 'FN': 68}
# PRON: {'TP': 524, 'FP': 58, 'TN': 18170, 'FN': 7}
# NUM: {'TP': 301, 'FP': 6, 'TN': 18394, 'FN': 58}
# X: {'TP': 14, 'FP': 2, 'TN': 18722, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 620 counts.
# Tag with the most false negative is:  ADJ with 460 counts.
# sentence:       ['Crime', ':', "'", 'skyjacked', "'", 'From', 'International', 'Airport', 'in', 'Los', 'Angeles', 'to', 'International', 'Airport', 'in', 'Houston', ',', 'as', 'the', 'great', 'four-jet', 'Boeing', '707', 'flies', ',', 'is', 'a', 'routine', 'five', 'hours', 'and', '25', 'minutes', ',', 'including', 'stopovers', 'at', 'Phoenix', ',', 'El', 'Paso', ',', 'and', 'San', 'Antonio', '.']
# hidden s:       ['NOUN', '.', '.', 'VERB', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'NUM', 'VERB', '.', 'VERB', 'DET', 'ADJ', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', '.', 'NOUN', '.', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'DET', 'ADJ', 'NUM', 'NOUN', 'CONJ', 'NUM', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2255, 'FP': 240, 'TN': 16283, 'FN': 27}
# NOUN: {'TP': 4500, 'FP': 623, 'TN': 13338, 'FN': 344}
# ADJ: {'TP': 1084, 'FP': 115, 'TN': 17145, 'FN': 461}
# VERB: {'TP': 2339, 'FP': 182, 'TN': 15935, 'FN': 349}
# ADP: {'TP': 2255, 'FP': 222, 'TN': 16241, 'FN': 87}
# .: {'TP': 2281, 'FP': 51, 'TN': 16473, 'FN': 0}
# ADV: {'TP': 656, 'FP': 64, 'TN': 17908, 'FN': 177}
# CONJ: {'TP': 567, 'FP': 4, 'TN': 18227, 'FN': 7}
# PRT: {'TP': 420, 'FP': 40, 'TN': 18277, 'FN': 68}
# PRON: {'TP': 524, 'FP': 58, 'TN': 18216, 'FN': 7}
# NUM: {'TP': 303, 'FP': 6, 'TN': 18437, 'FN': 59}
# X: {'TP': 14, 'FP': 2, 'TN': 18768, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 623 counts.
# Tag with the most false negative is:  ADJ with 461 counts.
# sentence:       ['When', 'Continental', 'Airlines', 'night-coach', 'Flight', '54', 'took', 'off', 'at', '11:30', 'one', 'night', 'last', 'week', ',', 'there', 'was', 'no', 'reason', 'to', 'think', 'it', 'would', 'take', 'any', 'longer', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'NUM', 'VERB', 'PRT', 'ADP', 'NUM', 'NUM', 'NOUN', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'ADJ', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'NOUN', 'ADP', 'NUM', 'VERB', 'PRT', 'ADP', 'NUM', 'NUM', 'NOUN', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'PRON', 'VERB', 'VERB', 'DET', 'ADV', '.']
# DET: {'TP': 2257, 'FP': 240, 'TN': 16308, 'FN': 27}
# NOUN: {'TP': 4505, 'FP': 623, 'TN': 13359, 'FN': 345}
# ADJ: {'TP': 1086, 'FP': 115, 'TN': 17169, 'FN': 462}
# VERB: {'TP': 2344, 'FP': 182, 'TN': 15957, 'FN': 349}
# ADP: {'TP': 2256, 'FP': 223, 'TN': 16266, 'FN': 87}
# .: {'TP': 2283, 'FP': 51, 'TN': 16498, 'FN': 0}
# ADV: {'TP': 657, 'FP': 65, 'TN': 17933, 'FN': 177}
# CONJ: {'TP': 567, 'FP': 4, 'TN': 18254, 'FN': 7}
# PRT: {'TP': 423, 'FP': 40, 'TN': 18301, 'FN': 68}
# PRON: {'TP': 525, 'FP': 58, 'TN': 18242, 'FN': 7}
# NUM: {'TP': 306, 'FP': 6, 'TN': 18461, 'FN': 59}
# X: {'TP': 14, 'FP': 2, 'TN': 18795, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 623 counts.
# Tag with the most false negative is:  ADJ with 462 counts.
# sentence:       ['The', 'plane', 'put', 'down', 'on', 'schedule', 'at', '1:35', 'a.m.', 'in', 'Phoenix', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'PRT', 'ADP', 'NOUN', 'ADP', 'NUM', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'PRT', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# DET: {'TP': 2258, 'FP': 240, 'TN': 16319, 'FN': 27}
# NOUN: {'TP': 4508, 'FP': 624, 'TN': 13367, 'FN': 345}
# ADJ: {'TP': 1086, 'FP': 115, 'TN': 17181, 'FN': 462}
# VERB: {'TP': 2345, 'FP': 182, 'TN': 15968, 'FN': 349}
# ADP: {'TP': 2259, 'FP': 223, 'TN': 16275, 'FN': 87}
# .: {'TP': 2284, 'FP': 51, 'TN': 16509, 'FN': 0}
# ADV: {'TP': 658, 'FP': 65, 'TN': 17944, 'FN': 177}
# CONJ: {'TP': 567, 'FP': 4, 'TN': 18266, 'FN': 7}
# PRT: {'TP': 424, 'FP': 40, 'TN': 18312, 'FN': 68}
# PRON: {'TP': 525, 'FP': 58, 'TN': 18254, 'FN': 7}
# NUM: {'TP': 306, 'FP': 6, 'TN': 18472, 'FN': 60}
# X: {'TP': 14, 'FP': 2, 'TN': 18807, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 624 counts.
# Tag with the most false negative is:  ADJ with 462 counts.
# sentence:       ['Thirty-one', 'minutes', 'later', ',', 'when', 'it', 'took', 'off', 'for', 'El', 'Paso', ',', 'hardly', 'anyone', 'of', 'the', 'crew', 'of', 'six', 'or', 'the', '65', 'other', 'passengers', 'paid', 'any', 'attention', 'to', 'the', 'man', 'and', 'teen-age', 'boy', 'who', 'had', 'come', 'aboard', '.']
# hidden s:       ['NUM', 'NOUN', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'CONJ', 'DET', 'NUM', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# predictions:    ['ADJ', 'NOUN', 'ADV', '.', 'ADV', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'CONJ', 'DET', 'NUM', 'ADJ', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# DET: {'TP': 2262, 'FP': 240, 'TN': 16353, 'FN': 27}
# NOUN: {'TP': 4517, 'FP': 625, 'TN': 13395, 'FN': 345}
# ADJ: {'TP': 1087, 'FP': 116, 'TN': 17216, 'FN': 463}
# VERB: {'TP': 2349, 'FP': 182, 'TN': 16002, 'FN': 349}
# ADP: {'TP': 2263, 'FP': 223, 'TN': 16309, 'FN': 87}
# .: {'TP': 2287, 'FP': 51, 'TN': 16544, 'FN': 0}
# ADV: {'TP': 662, 'FP': 65, 'TN': 17978, 'FN': 177}
# CONJ: {'TP': 569, 'FP': 4, 'TN': 18302, 'FN': 7}
# PRT: {'TP': 425, 'FP': 40, 'TN': 18349, 'FN': 68}
# PRON: {'TP': 527, 'FP': 58, 'TN': 18290, 'FN': 7}
# NUM: {'TP': 308, 'FP': 6, 'TN': 18507, 'FN': 61}
# X: {'TP': 14, 'FP': 2, 'TN': 18845, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 625 counts.
# Tag with the most false negative is:  ADJ with 463 counts.
# sentence:       ['At', '3:57', 'a.m.', ',', 'with', 'the', 'plane', 'about', 'twenty', 'minutes', 'out', 'of', 'El', 'Paso', ',', 'passenger', 'Robert', 'Berry', ',', 'a', 'San', 'Antonio', 'advertising', 'man', ',', 'glanced', 'up', 'and', 'saw', 'the', 'man', 'and', 'boy', ',', 'accompanied', 'by', 'a', 'stewardess', ',', 'walking', 'up', 'the', 'aisle', 'toward', 'the', 'cockpit', '.']
# hidden s:       ['ADP', 'NUM', 'ADV', '.', 'ADP', 'DET', 'NOUN', 'ADV', 'NUM', 'NOUN', 'ADP', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'CONJ', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'ADV', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', 'PRT', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'PRT', 'CONJ', 'VERB', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'PRT', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2268, 'FP': 240, 'TN': 16394, 'FN': 27}
# NOUN: {'TP': 4532, 'FP': 627, 'TN': 13425, 'FN': 345}
# ADJ: {'TP': 1087, 'FP': 116, 'TN': 17263, 'FN': 463}
# VERB: {'TP': 2353, 'FP': 182, 'TN': 16044, 'FN': 350}
# ADP: {'TP': 2268, 'FP': 224, 'TN': 16348, 'FN': 89}
# .: {'TP': 2294, 'FP': 51, 'TN': 16584, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18023, 'FN': 178}
# CONJ: {'TP': 571, 'FP': 4, 'TN': 18347, 'FN': 7}
# PRT: {'TP': 426, 'FP': 42, 'TN': 18393, 'FN': 68}
# PRON: {'TP': 527, 'FP': 58, 'TN': 18337, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18552, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18892, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 627 counts.
# Tag with the most false negative is:  ADJ with 463 counts.
# sentence:       ['``', 'The', 'man', 'was', 'bent', 'over', 'with', 'his', 'hand', 'on', 'his', 'stomach', "''", ',', 'Berry', 'said', '.']
# hidden s:       ['.', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'NOUN', 'VERB', '.']
# predictions:    ['.', 'DET', 'NOUN', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'NOUN', 'VERB', '.']
# DET: {'TP': 2271, 'FP': 240, 'TN': 16408, 'FN': 27}
# NOUN: {'TP': 4536, 'FP': 627, 'TN': 13438, 'FN': 345}
# ADJ: {'TP': 1087, 'FP': 116, 'TN': 17280, 'FN': 463}
# VERB: {'TP': 2356, 'FP': 182, 'TN': 16058, 'FN': 350}
# ADP: {'TP': 2270, 'FP': 224, 'TN': 16363, 'FN': 89}
# .: {'TP': 2298, 'FP': 51, 'TN': 16597, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18040, 'FN': 178}
# CONJ: {'TP': 571, 'FP': 4, 'TN': 18364, 'FN': 7}
# PRT: {'TP': 427, 'FP': 42, 'TN': 18409, 'FN': 68}
# PRON: {'TP': 527, 'FP': 58, 'TN': 18354, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18569, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18909, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 627 counts.
# Tag with the most false negative is:  ADJ with 463 counts.
# sentence:       ['``', 'I', 'figured', 'he', 'was', 'sick', "''", '.']
# hidden s:       ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'ADJ', '.', '.']
# predictions:    ['.', 'PRON', 'VERB', 'PRON', 'VERB', 'NOUN', '.', '.']
# DET: {'TP': 2271, 'FP': 240, 'TN': 16416, 'FN': 27}
# NOUN: {'TP': 4536, 'FP': 628, 'TN': 13445, 'FN': 345}
# ADJ: {'TP': 1087, 'FP': 116, 'TN': 17287, 'FN': 464}
# VERB: {'TP': 2358, 'FP': 182, 'TN': 16064, 'FN': 350}
# ADP: {'TP': 2270, 'FP': 224, 'TN': 16371, 'FN': 89}
# .: {'TP': 2301, 'FP': 51, 'TN': 16602, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18048, 'FN': 178}
# CONJ: {'TP': 571, 'FP': 4, 'TN': 18372, 'FN': 7}
# PRT: {'TP': 427, 'FP': 42, 'TN': 18417, 'FN': 68}
# PRON: {'TP': 529, 'FP': 58, 'TN': 18360, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18577, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18917, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 628 counts.
# Tag with the most false negative is:  ADJ with 464 counts.
# sentence:       ['John', 'Salvador', ',', 'a', 'farmer', 'from', 'Palm', 'Desert', ',', 'Calif.', ',', 'was', 'sitting', 'up', 'front', 'and', 'could', 'see', 'through', 'the', 'door', 'as', 'the', 'trio', 'entered', 'the', 'cockpit', '.']
# hidden s:       ['NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'VERB', 'VERB', 'ADP', 'NOUN', 'CONJ', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'VERB', 'VERB', 'PRT', 'NOUN', 'CONJ', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2275, 'FP': 240, 'TN': 16440, 'FN': 27}
# NOUN: {'TP': 4546, 'FP': 628, 'TN': 13463, 'FN': 345}
# ADJ: {'TP': 1087, 'FP': 116, 'TN': 17315, 'FN': 464}
# VERB: {'TP': 2363, 'FP': 182, 'TN': 16087, 'FN': 350}
# ADP: {'TP': 2273, 'FP': 224, 'TN': 16395, 'FN': 90}
# .: {'TP': 2305, 'FP': 51, 'TN': 16626, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18076, 'FN': 178}
# CONJ: {'TP': 572, 'FP': 4, 'TN': 18399, 'FN': 7}
# PRT: {'TP': 427, 'FP': 43, 'TN': 18444, 'FN': 68}
# PRON: {'TP': 529, 'FP': 58, 'TN': 18388, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18605, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18945, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 628 counts.
# Tag with the most false negative is:  ADJ with 464 counts.
# sentence:       ['``', 'The', 'kid', 'had', 'a', 'automatic', ',', 'like', 'they', 'issue', 'in', 'the', 'Army', "''", ',', 'he', 'said', '.']
# hidden s:       ['.', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', '.', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', '.']
# predictions:    ['.', 'DET', 'NOUN', 'VERB', 'DET', 'ADJ', '.', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', '.']
# DET: {'TP': 2278, 'FP': 240, 'TN': 16455, 'FN': 27}
# NOUN: {'TP': 4548, 'FP': 628, 'TN': 13479, 'FN': 345}
# ADJ: {'TP': 1088, 'FP': 116, 'TN': 17332, 'FN': 464}
# VERB: {'TP': 2366, 'FP': 182, 'TN': 16102, 'FN': 350}
# ADP: {'TP': 2275, 'FP': 224, 'TN': 16411, 'FN': 90}
# .: {'TP': 2310, 'FP': 51, 'TN': 16639, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18094, 'FN': 178}
# CONJ: {'TP': 572, 'FP': 4, 'TN': 18417, 'FN': 7}
# PRT: {'TP': 427, 'FP': 43, 'TN': 18462, 'FN': 68}
# PRON: {'TP': 531, 'FP': 58, 'TN': 18404, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18623, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18963, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 628 counts.
# Tag with the most false negative is:  ADJ with 464 counts.
# sentence:       ['``', 'The', 'other', 'fellow', 'had', 'a', "''", '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', '.', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'DET', '.', '.']
# DET: {'TP': 2280, 'FP': 240, 'TN': 16461, 'FN': 27}
# NOUN: {'TP': 4549, 'FP': 628, 'TN': 13486, 'FN': 345}
# ADJ: {'TP': 1089, 'FP': 116, 'TN': 17339, 'FN': 464}
# VERB: {'TP': 2367, 'FP': 182, 'TN': 16109, 'FN': 350}
# ADP: {'TP': 2275, 'FP': 224, 'TN': 16419, 'FN': 90}
# .: {'TP': 2313, 'FP': 51, 'TN': 16644, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18102, 'FN': 178}
# CONJ: {'TP': 572, 'FP': 4, 'TN': 18425, 'FN': 7}
# PRT: {'TP': 427, 'FP': 43, 'TN': 18470, 'FN': 68}
# PRON: {'TP': 531, 'FP': 58, 'TN': 18412, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18631, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18971, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 628 counts.
# Tag with the most false negative is:  ADJ with 464 counts.
# sentence:       ['Salvador', 'saw', 'the', 'youth', 'hold', 'his', 'against', 'the', 'head', 'of', 'stewardess', 'Lois', 'Carnegey', ';', ';', 'the', 'man', 'put', 'his', 'at', 'the', 'head', 'of', 'Capt.', 'Byron', 'D.', 'Rickards', '.']
# hidden s:       ['NOUN', 'VERB', 'DET', 'NOUN', 'NOUN', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'DET', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2286, 'FP': 241, 'TN': 16482, 'FN': 27}
# NOUN: {'TP': 4559, 'FP': 628, 'TN': 13501, 'FN': 348}
# ADJ: {'TP': 1089, 'FP': 116, 'TN': 17367, 'FN': 464}
# VERB: {'TP': 2369, 'FP': 183, 'TN': 16134, 'FN': 350}
# ADP: {'TP': 2279, 'FP': 224, 'TN': 16443, 'FN': 90}
# .: {'TP': 2316, 'FP': 51, 'TN': 16669, 'FN': 0}
# ADV: {'TP': 663, 'FP': 65, 'TN': 18130, 'FN': 178}
# CONJ: {'TP': 572, 'FP': 4, 'TN': 18453, 'FN': 7}
# PRT: {'TP': 427, 'FP': 43, 'TN': 18498, 'FN': 68}
# PRON: {'TP': 531, 'FP': 59, 'TN': 18439, 'FN': 7}
# NUM: {'TP': 309, 'FP': 6, 'TN': 18659, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 18999, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 628 counts.
# Tag with the most false negative is:  ADJ with 464 counts.
# sentence:       ['To', 'Rickards', ',', 'a', '52-year-old', 'veteran', '30', 'years', 'in', 'the', 'air', ',', 'it', 'was', 'an', 'old', 'story', ':', 'His', 'plane', 'was', 'being', 'hijacked', 'in', 'mid-flight', 'again', 'much', 'as', 'it', 'had', 'happened', 'in', '1930', ',', 'when', 'Peruvian', 'rebels', 'made', 'him', 'land', 'a', 'Ford', 'tri-motor', 'at', 'Arequipa', '.']
# hidden s:       ['ADP', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'NUM', '.', 'ADV', 'ADJ', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['PRT', 'VERB', '.', 'DET', 'NOUN', 'NOUN', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADV', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'NUM', '.', 'ADV', 'ADJ', 'NOUN', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2291, 'FP': 241, 'TN': 16523, 'FN': 27}
# NOUN: {'TP': 4569, 'FP': 629, 'TN': 13535, 'FN': 349}
# ADJ: {'TP': 1091, 'FP': 116, 'TN': 17409, 'FN': 466}
# VERB: {'TP': 2377, 'FP': 184, 'TN': 16171, 'FN': 350}
# ADP: {'TP': 2284, 'FP': 224, 'TN': 16483, 'FN': 91}
# .: {'TP': 2321, 'FP': 51, 'TN': 16710, 'FN': 0}
# ADV: {'TP': 665, 'FP': 66, 'TN': 18173, 'FN': 178}
# CONJ: {'TP': 572, 'FP': 4, 'TN': 18499, 'FN': 7}
# PRT: {'TP': 427, 'FP': 44, 'TN': 18543, 'FN': 68}
# PRON: {'TP': 534, 'FP': 59, 'TN': 18482, 'FN': 7}
# NUM: {'TP': 311, 'FP': 6, 'TN': 18703, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 19045, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 629 counts.
# Tag with the most false negative is:  ADJ with 466 counts.
# sentence:       ['But', 'last', "week's", 'pirates', ',', 'like', 'the', 'Cuban-American', 'who', 'recently', 'hijacked', 'an', 'Eastern', 'Airlines', 'Electra', '(', 'Newsweek', ',', 'Aug.', '7', ')', ',', 'wanted', 'to', 'go', 'to', 'Havana', '.']
# hidden s:       ['CONJ', 'ADJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'PRON', 'ADV', 'VERB', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'NUM', '.', '.', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', '.']
# predictions:    ['CONJ', 'ADJ', 'NOUN', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'PRON', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', '.', 'NOUN', 'NUM', '.', '.', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', '.']
# DET: {'TP': 2293, 'FP': 241, 'TN': 16549, 'FN': 27}
# NOUN: {'TP': 4577, 'FP': 629, 'TN': 13555, 'FN': 349}
# ADJ: {'TP': 1093, 'FP': 116, 'TN': 17435, 'FN': 466}
# VERB: {'TP': 2379, 'FP': 184, 'TN': 16196, 'FN': 351}
# ADP: {'TP': 2286, 'FP': 225, 'TN': 16508, 'FN': 91}
# .: {'TP': 2327, 'FP': 51, 'TN': 16732, 'FN': 0}
# ADV: {'TP': 666, 'FP': 66, 'TN': 18200, 'FN': 178}
# CONJ: {'TP': 573, 'FP': 4, 'TN': 18526, 'FN': 7}
# PRT: {'TP': 428, 'FP': 44, 'TN': 18570, 'FN': 68}
# PRON: {'TP': 535, 'FP': 59, 'TN': 18509, 'FN': 7}
# NUM: {'TP': 312, 'FP': 6, 'TN': 18730, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 19073, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 629 counts.
# Tag with the most false negative is:  ADJ with 466 counts.
# sentence:       ['Stalling', ':', '``', 'Tell', 'your', 'company', 'there', 'are', 'four', 'of', 'us', 'here', 'with', 'guns', "''", ',', 'the', 'elder', 'man', 'told', 'Rickards', '.']
# hidden s:       ['VERB', '.', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'PRON', 'ADV', 'ADP', 'NOUN', '.', '.', 'DET', 'ADJ', 'NOUN', 'VERB', 'NOUN', '.']
# predictions:    ['NOUN', '.', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'NUM', 'ADP', 'PRON', 'ADV', 'ADP', 'NOUN', '.', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'NOUN', '.']
# DET: {'TP': 2295, 'FP': 241, 'TN': 16569, 'FN': 27}
# NOUN: {'TP': 4581, 'FP': 631, 'TN': 13571, 'FN': 349}
# ADJ: {'TP': 1093, 'FP': 116, 'TN': 17456, 'FN': 467}
# VERB: {'TP': 2382, 'FP': 184, 'TN': 16214, 'FN': 352}
# ADP: {'TP': 2288, 'FP': 225, 'TN': 16528, 'FN': 91}
# .: {'TP': 2332, 'FP': 51, 'TN': 16749, 'FN': 0}
# ADV: {'TP': 667, 'FP': 66, 'TN': 18221, 'FN': 178}
# CONJ: {'TP': 573, 'FP': 4, 'TN': 18548, 'FN': 7}
# PRT: {'TP': 429, 'FP': 44, 'TN': 18591, 'FN': 68}
# PRON: {'TP': 536, 'FP': 59, 'TN': 18530, 'FN': 7}
# NUM: {'TP': 313, 'FP': 6, 'TN': 18751, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 19095, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 631 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['The', 'pilot', 'radioed', 'El', 'Paso', 'International', 'Airport', 'with', 'just', 'that', 'message', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'ADV', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'ADV', 'ADP', 'NOUN', '.']
# DET: {'TP': 2296, 'FP': 241, 'TN': 16579, 'FN': 28}
# NOUN: {'TP': 4586, 'FP': 632, 'TN': 13577, 'FN': 349}
# ADJ: {'TP': 1094, 'FP': 116, 'TN': 17467, 'FN': 467}
# VERB: {'TP': 2382, 'FP': 184, 'TN': 16225, 'FN': 353}
# ADP: {'TP': 2289, 'FP': 226, 'TN': 16538, 'FN': 91}
# .: {'TP': 2333, 'FP': 51, 'TN': 16760, 'FN': 0}
# ADV: {'TP': 668, 'FP': 66, 'TN': 18232, 'FN': 178}
# CONJ: {'TP': 573, 'FP': 4, 'TN': 18560, 'FN': 7}
# PRT: {'TP': 429, 'FP': 44, 'TN': 18603, 'FN': 68}
# PRON: {'TP': 536, 'FP': 59, 'TN': 18542, 'FN': 7}
# NUM: {'TP': 313, 'FP': 6, 'TN': 18763, 'FN': 62}
# X: {'TP': 14, 'FP': 2, 'TN': 19107, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 632 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['But', ',', 'he', 'told', 'the', '``', 'skyjackers', "''", ',', 'the', '707', "didn't", 'carry', 'enough', 'fuel', 'to', 'reach', 'Havana', ';', ';', 'they', 'would', 'have', 'to', 'refuel', 'at', 'El', 'Paso', '.']
# hidden s:       ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NUM', 'VERB', 'VERB', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['CONJ', '.', 'PRON', 'VERB', 'DET', '.', 'NOUN', '.', '.', 'DET', 'NOUN', 'VERB', 'VERB', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', '.', '.', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2298, 'FP': 241, 'TN': 16606, 'FN': 28}
# NOUN: {'TP': 4591, 'FP': 633, 'TN': 13600, 'FN': 349}
# ADJ: {'TP': 1095, 'FP': 116, 'TN': 17495, 'FN': 467}
# VERB: {'TP': 2389, 'FP': 184, 'TN': 16247, 'FN': 353}
# ADP: {'TP': 2290, 'FP': 226, 'TN': 16566, 'FN': 91}
# .: {'TP': 2340, 'FP': 51, 'TN': 16782, 'FN': 0}
# ADV: {'TP': 668, 'FP': 66, 'TN': 18261, 'FN': 178}
# CONJ: {'TP': 574, 'FP': 4, 'TN': 18588, 'FN': 7}
# PRT: {'TP': 431, 'FP': 44, 'TN': 18630, 'FN': 68}
# PRON: {'TP': 538, 'FP': 59, 'TN': 18569, 'FN': 7}
# NUM: {'TP': 313, 'FP': 6, 'TN': 18791, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19136, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 633 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['Most', 'passengers', "didn't", 'know', 'what', 'had', 'happened', 'until', 'they', 'got', 'on', 'the', 'ground', '.']
# hidden s:       ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'VERB', 'VERB', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2300, 'FP': 241, 'TN': 16618, 'FN': 28}
# NOUN: {'TP': 4593, 'FP': 633, 'TN': 13612, 'FN': 349}
# ADJ: {'TP': 1096, 'FP': 116, 'TN': 17508, 'FN': 467}
# VERB: {'TP': 2394, 'FP': 184, 'TN': 16256, 'FN': 353}
# ADP: {'TP': 2292, 'FP': 226, 'TN': 16578, 'FN': 91}
# .: {'TP': 2341, 'FP': 51, 'TN': 16795, 'FN': 0}
# ADV: {'TP': 668, 'FP': 66, 'TN': 18275, 'FN': 178}
# CONJ: {'TP': 574, 'FP': 4, 'TN': 18602, 'FN': 7}
# PRT: {'TP': 431, 'FP': 44, 'TN': 18644, 'FN': 68}
# PRON: {'TP': 539, 'FP': 59, 'TN': 18582, 'FN': 7}
# NUM: {'TP': 313, 'FP': 6, 'TN': 18805, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19150, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 633 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['Jerry', 'McCauley', 'of', 'Sacramento', ',', 'Calif.', ',', 'one', 'of', 'some', 'twenty', 'Air', 'Force', 'recruits', 'on', 'board', ',', 'awoke', 'from', 'a', 'nap', 'in', 'confusion', '.']
# hidden s:       ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'NUM', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2302, 'FP': 241, 'TN': 16640, 'FN': 28}
# NOUN: {'TP': 4603, 'FP': 634, 'TN': 13625, 'FN': 349}
# ADJ: {'TP': 1096, 'FP': 116, 'TN': 17532, 'FN': 467}
# VERB: {'TP': 2394, 'FP': 184, 'TN': 16279, 'FN': 354}
# ADP: {'TP': 2297, 'FP': 226, 'TN': 16597, 'FN': 91}
# .: {'TP': 2345, 'FP': 51, 'TN': 16815, 'FN': 0}
# ADV: {'TP': 668, 'FP': 66, 'TN': 18299, 'FN': 178}
# CONJ: {'TP': 574, 'FP': 4, 'TN': 18626, 'FN': 7}
# PRT: {'TP': 431, 'FP': 44, 'TN': 18668, 'FN': 68}
# PRON: {'TP': 539, 'FP': 59, 'TN': 18606, 'FN': 7}
# NUM: {'TP': 315, 'FP': 6, 'TN': 18827, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19174, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 634 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['``', 'The', 'old', 'man', 'came', 'from', 'the', 'front', 'of', 'the', 'plane', 'and', 'said', 'he', 'wanted', 'four', 'volunteers', 'to', 'go', 'to', 'Cuba', "''", ',', 'McCauley', 'said', ',', '``', 'and', 'like', 'a', 'nut', 'I', 'raised', 'my', 'hand', '.']
# hidden s:       ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', '.', 'NOUN', 'VERB', '.', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'VERB', 'PRON', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', '.', 'PRON', 'VERB', '.', '.', 'CONJ', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2307, 'FP': 241, 'TN': 16671, 'FN': 28}
# NOUN: {'TP': 4610, 'FP': 634, 'TN': 13653, 'FN': 350}
# ADJ: {'TP': 1097, 'FP': 116, 'TN': 17567, 'FN': 467}
# VERB: {'TP': 2400, 'FP': 184, 'TN': 16309, 'FN': 354}
# ADP: {'TP': 2301, 'FP': 226, 'TN': 16629, 'FN': 91}
# .: {'TP': 2351, 'FP': 51, 'TN': 16845, 'FN': 0}
# ADV: {'TP': 668, 'FP': 66, 'TN': 18335, 'FN': 178}
# CONJ: {'TP': 576, 'FP': 4, 'TN': 18660, 'FN': 7}
# PRT: {'TP': 432, 'FP': 44, 'TN': 18703, 'FN': 68}
# PRON: {'TP': 541, 'FP': 60, 'TN': 18639, 'FN': 7}
# NUM: {'TP': 316, 'FP': 6, 'TN': 18862, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19210, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 634 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['I', 'thought', 'he', 'was', 'the', 'Air', 'Force', 'recruiter', "''", '.']
# hidden s:       ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# predictions:    ['PRON', 'VERB', 'PRON', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', '.', '.']
# DET: {'TP': 2308, 'FP': 241, 'TN': 16680, 'FN': 28}
# NOUN: {'TP': 4613, 'FP': 634, 'TN': 13660, 'FN': 350}
# ADJ: {'TP': 1097, 'FP': 116, 'TN': 17577, 'FN': 467}
# VERB: {'TP': 2402, 'FP': 184, 'TN': 16317, 'FN': 354}
# ADP: {'TP': 2301, 'FP': 226, 'TN': 16639, 'FN': 91}
# .: {'TP': 2353, 'FP': 51, 'TN': 16853, 'FN': 0}
# ADV: {'TP': 668, 'FP': 66, 'TN': 18345, 'FN': 178}
# CONJ: {'TP': 576, 'FP': 4, 'TN': 18670, 'FN': 7}
# PRT: {'TP': 432, 'FP': 44, 'TN': 18713, 'FN': 68}
# PRON: {'TP': 543, 'FP': 60, 'TN': 18647, 'FN': 7}
# NUM: {'TP': 316, 'FP': 6, 'TN': 18872, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19220, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 634 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['What', 'the', 'man', 'wanted', 'was', 'four', 'persons', 'to', 'volunteer', 'as', 'hostages', ',', 'along', 'with', 'the', 'crew', '.']
# hidden s:       ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'ADP', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'DET', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'PRT', 'VERB', 'ADP', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2311, 'FP': 241, 'TN': 16694, 'FN': 28}
# NOUN: {'TP': 4617, 'FP': 634, 'TN': 13673, 'FN': 350}
# ADJ: {'TP': 1097, 'FP': 116, 'TN': 17594, 'FN': 467}
# VERB: {'TP': 2405, 'FP': 184, 'TN': 16331, 'FN': 354}
# ADP: {'TP': 2303, 'FP': 226, 'TN': 16653, 'FN': 92}
# .: {'TP': 2355, 'FP': 51, 'TN': 16868, 'FN': 0}
# ADV: {'TP': 668, 'FP': 67, 'TN': 18361, 'FN': 178}
# CONJ: {'TP': 576, 'FP': 4, 'TN': 18687, 'FN': 7}
# PRT: {'TP': 433, 'FP': 44, 'TN': 18729, 'FN': 68}
# PRON: {'TP': 543, 'FP': 60, 'TN': 18664, 'FN': 7}
# NUM: {'TP': 317, 'FP': 6, 'TN': 18888, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19237, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 634 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['They', 'chose', 'four', ':', 'Jack', 'Casey', ',', 'who', 'works', 'for', 'Continental', 'Airlines', 'in', 'Houston', ';', ';', 'Fred', 'Mullen', 'from', 'Mercer', 'Island', ',', 'Wash.', ';', ';', 'Pfc.', 'Truman', 'Cleveland', 'of', 'St.', 'Augustine', '.']
# hidden s:       ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'NUM', '.', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', '.', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'NOUN', '.', '.', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2311, 'FP': 242, 'TN': 16725, 'FN': 28}
# NOUN: {'TP': 4630, 'FP': 634, 'TN': 13691, 'FN': 351}
# ADJ: {'TP': 1098, 'FP': 116, 'TN': 17625, 'FN': 467}
# VERB: {'TP': 2407, 'FP': 184, 'TN': 16361, 'FN': 354}
# ADP: {'TP': 2307, 'FP': 226, 'TN': 16681, 'FN': 92}
# .: {'TP': 2363, 'FP': 51, 'TN': 16892, 'FN': 0}
# ADV: {'TP': 668, 'FP': 67, 'TN': 18393, 'FN': 178}
# CONJ: {'TP': 576, 'FP': 4, 'TN': 18719, 'FN': 7}
# PRT: {'TP': 433, 'FP': 44, 'TN': 18761, 'FN': 68}
# PRON: {'TP': 545, 'FP': 60, 'TN': 18694, 'FN': 7}
# NUM: {'TP': 318, 'FP': 6, 'TN': 18919, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19269, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 634 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['Fla.', ',', 'and', 'Leonard', 'Gilman', ',', 'a', 'former', 'college', 'boxer', 'and', 'veteran', 'of', 'the', 'U.S.', 'Immigration', 'Service', 'Border', 'Patrol', '.']
# hidden s:       ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'DET', 'ADJ', 'NOUN', '.', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2313, 'FP': 242, 'TN': 16743, 'FN': 28}
# NOUN: {'TP': 4640, 'FP': 634, 'TN': 13700, 'FN': 352}
# ADJ: {'TP': 1099, 'FP': 116, 'TN': 17644, 'FN': 467}
# VERB: {'TP': 2407, 'FP': 184, 'TN': 16381, 'FN': 354}
# ADP: {'TP': 2308, 'FP': 226, 'TN': 16700, 'FN': 92}
# .: {'TP': 2366, 'FP': 52, 'TN': 16908, 'FN': 0}
# ADV: {'TP': 668, 'FP': 67, 'TN': 18413, 'FN': 178}
# CONJ: {'TP': 578, 'FP': 4, 'TN': 18737, 'FN': 7}
# PRT: {'TP': 433, 'FP': 44, 'TN': 18781, 'FN': 68}
# PRON: {'TP': 545, 'FP': 60, 'TN': 18714, 'FN': 7}
# NUM: {'TP': 318, 'FP': 6, 'TN': 18939, 'FN': 63}
# X: {'TP': 14, 'FP': 2, 'TN': 19289, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 634 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['Everybody', 'else', 'was', 'allowed', 'to', 'file', 'off', 'the', 'plane', 'after', 'it', 'touched', 'down', 'at', 'El', 'Paso', 'at', '4:18', 'a.m.', '.']
# hidden s:       ['NOUN', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NUM', 'ADV', '.']
# predictions:    ['NOUN', 'ADV', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'PRT', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADV', '.']
# DET: {'TP': 2314, 'FP': 242, 'TN': 16762, 'FN': 28}
# NOUN: {'TP': 4644, 'FP': 636, 'TN': 13714, 'FN': 352}
# ADJ: {'TP': 1099, 'FP': 116, 'TN': 17664, 'FN': 467}
# VERB: {'TP': 2410, 'FP': 184, 'TN': 16397, 'FN': 355}
# ADP: {'TP': 2312, 'FP': 227, 'TN': 16715, 'FN': 92}
# .: {'TP': 2367, 'FP': 52, 'TN': 16927, 'FN': 0}
# ADV: {'TP': 670, 'FP': 67, 'TN': 18431, 'FN': 178}
# CONJ: {'TP': 578, 'FP': 4, 'TN': 18757, 'FN': 7}
# PRT: {'TP': 434, 'FP': 44, 'TN': 18799, 'FN': 69}
# PRON: {'TP': 546, 'FP': 60, 'TN': 18733, 'FN': 7}
# NUM: {'TP': 318, 'FP': 6, 'TN': 18958, 'FN': 64}
# X: {'TP': 14, 'FP': 2, 'TN': 19309, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 636 counts.
# Tag with the most false negative is:  ADJ with 467 counts.
# sentence:       ['They', 'found', 'a', 'large', 'welcoming', 'group', '--', 'El', 'Paso', 'policemen', ',', 'Border', 'Patrol', ',', "sheriff's", 'deputies', ',', 'and', 'FBI', 'men', ',', 'who', 'surged', 'around', 'the', 'plane', 'with', 'rifles', 'and', 'submachine', 'guns', '.']
# hidden s:       ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'DET', 'ADJ', 'VERB', 'NOUN', '.', 'NOUN', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', '.', 'DET', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2316, 'FP': 244, 'TN': 16790, 'FN': 28}
# NOUN: {'TP': 4655, 'FP': 637, 'TN': 13732, 'FN': 354}
# ADJ: {'TP': 1100, 'FP': 116, 'TN': 17694, 'FN': 468}
# VERB: {'TP': 2413, 'FP': 184, 'TN': 16426, 'FN': 355}
# ADP: {'TP': 2314, 'FP': 227, 'TN': 16745, 'FN': 92}
# .: {'TP': 2373, 'FP': 52, 'TN': 16953, 'FN': 0}
# ADV: {'TP': 670, 'FP': 67, 'TN': 18463, 'FN': 178}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18787, 'FN': 7}
# PRT: {'TP': 434, 'FP': 44, 'TN': 18831, 'FN': 69}
# PRON: {'TP': 548, 'FP': 60, 'TN': 18763, 'FN': 7}
# NUM: {'TP': 318, 'FP': 6, 'TN': 18990, 'FN': 64}
# X: {'TP': 14, 'FP': 2, 'TN': 19341, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 637 counts.
# Tag with the most false negative is:  ADJ with 468 counts.
# sentence:       ['Other', 'FBI', 'men', ',', 'talking', 'with', 'the', 'pilot', 'from', 'the', 'tower', ',', 'conspired', 'with', 'him', 'to', 'delay', 'the', 'proposed', 'flight', 'to', 'Havana', '.']
# hidden s:       ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'PRON', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADJ', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', 'ADP', 'PRON', 'ADP', 'NOUN', 'DET', 'VERB', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2319, 'FP': 244, 'TN': 16810, 'FN': 28}
# NOUN: {'TP': 4661, 'FP': 639, 'TN': 13747, 'FN': 354}
# ADJ: {'TP': 1101, 'FP': 116, 'TN': 17716, 'FN': 468}
# VERB: {'TP': 2415, 'FP': 184, 'TN': 16445, 'FN': 357}
# ADP: {'TP': 2318, 'FP': 228, 'TN': 16763, 'FN': 92}
# .: {'TP': 2376, 'FP': 52, 'TN': 16973, 'FN': 0}
# ADV: {'TP': 670, 'FP': 67, 'TN': 18486, 'FN': 178}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18810, 'FN': 7}
# PRT: {'TP': 434, 'FP': 44, 'TN': 18853, 'FN': 70}
# PRON: {'TP': 549, 'FP': 60, 'TN': 18785, 'FN': 7}
# NUM: {'TP': 318, 'FP': 6, 'TN': 19013, 'FN': 64}
# X: {'TP': 14, 'FP': 2, 'TN': 19364, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 639 counts.
# Tag with the most false negative is:  ADJ with 468 counts.
# sentence:       ['The', 'ground', 'crew', ',', 'which', 'ordinarily', 'fuels', 'a', '707', 'in', 'twenty', 'minutes', ',', 'took', 'fully', 'three', 'hours', '.']
# hidden s:       ['DET', 'NOUN', 'NOUN', '.', 'DET', 'ADV', 'VERB', 'DET', 'NUM', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NUM', 'NOUN', '.', 'VERB', 'ADV', 'NUM', 'NOUN', '.']
# DET: {'TP': 2322, 'FP': 244, 'TN': 16825, 'FN': 28}
# NOUN: {'TP': 4665, 'FP': 641, 'TN': 13759, 'FN': 354}
# ADJ: {'TP': 1101, 'FP': 116, 'TN': 17734, 'FN': 468}
# VERB: {'TP': 2416, 'FP': 184, 'TN': 16461, 'FN': 358}
# ADP: {'TP': 2319, 'FP': 229, 'TN': 16779, 'FN': 92}
# .: {'TP': 2379, 'FP': 52, 'TN': 16988, 'FN': 0}
# ADV: {'TP': 671, 'FP': 67, 'TN': 18502, 'FN': 179}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18828, 'FN': 7}
# PRT: {'TP': 434, 'FP': 44, 'TN': 18871, 'FN': 70}
# PRON: {'TP': 549, 'FP': 60, 'TN': 18803, 'FN': 7}
# NUM: {'TP': 320, 'FP': 6, 'TN': 19028, 'FN': 65}
# X: {'TP': 14, 'FP': 2, 'TN': 19382, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 641 counts.
# Tag with the most false negative is:  ADJ with 468 counts.
# sentence:       ['Still', 'more', 'time', 'was', 'consumed', 'while', 'the', 'pilot', ',', 'at', 'the', 'radioed', 'suggestion', 'of', 'Continental', 'president', 'Robert', 'Six', ',', 'tried', 'to', 'persuade', 'the', 'armed', 'pair', 'to', 'swap', 'the', 'Boeing', 'jet', 'for', 'a', 'propeller-driven', 'Douglas', 'Aj', '.']
# hidden s:       ['ADV', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NUM', '.', 'VERB', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2327, 'FP': 244, 'TN': 16856, 'FN': 28}
# NOUN: {'TP': 4675, 'FP': 643, 'TN': 13782, 'FN': 355}
# ADJ: {'TP': 1103, 'FP': 116, 'TN': 17767, 'FN': 469}
# VERB: {'TP': 2422, 'FP': 184, 'TN': 16490, 'FN': 359}
# ADP: {'TP': 2323, 'FP': 229, 'TN': 16811, 'FN': 92}
# .: {'TP': 2382, 'FP': 52, 'TN': 17021, 'FN': 0}
# ADV: {'TP': 672, 'FP': 67, 'TN': 18537, 'FN': 179}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18864, 'FN': 7}
# PRT: {'TP': 436, 'FP': 44, 'TN': 18905, 'FN': 70}
# PRON: {'TP': 549, 'FP': 60, 'TN': 18839, 'FN': 7}
# NUM: {'TP': 320, 'FP': 7, 'TN': 19063, 'FN': 65}
# X: {'TP': 14, 'FP': 2, 'TN': 19418, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 643 counts.
# Tag with the most false negative is:  ADJ with 469 counts.
# sentence:       ['Actually', ',', 'the', 'officers', 'on', 'the', 'ground', 'had', 'no', 'intention', 'of', 'letting', 'the', 'hijackers', 'get', 'away', 'with', 'any', 'kind', 'of', 'an', 'airplane', ';', ';', 'they', 'had', 'orders', 'to', 'that', 'effect', 'straight', 'from', 'President', 'Kennedy', ',', 'who', 'thought', 'at', 'first', ',', 'as', 'did', 'most', 'others', ',', 'that', 'it', 'was', 'four', 'followers', 'of', "Cuba's", 'Fidel', 'Castro', 'who', 'had', 'taken', 'over', 'the', '707', '.']
# hidden s:       ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADV', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADV', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'PRT', 'DET', 'NUM', '.']
# predictions:    ['ADV', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'VERB', 'DET', 'NOUN', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'PRON', 'VERB', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADV', 'ADP', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'ADJ', '.', 'ADV', 'VERB', 'ADJ', 'NOUN', '.', 'ADP', 'PRON', 'VERB', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2335, 'FP': 245, 'TN': 16908, 'FN': 28}
# NOUN: {'TP': 4688, 'FP': 645, 'TN': 13827, 'FN': 356}
# ADJ: {'TP': 1105, 'FP': 116, 'TN': 17825, 'FN': 470}
# VERB: {'TP': 2431, 'FP': 184, 'TN': 16542, 'FN': 359}
# ADP: {'TP': 2332, 'FP': 230, 'TN': 16862, 'FN': 92}
# .: {'TP': 2389, 'FP': 52, 'TN': 17075, 'FN': 0}
# ADV: {'TP': 676, 'FP': 67, 'TN': 18594, 'FN': 179}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18925, 'FN': 7}
# PRT: {'TP': 436, 'FP': 44, 'TN': 18965, 'FN': 71}
# PRON: {'TP': 553, 'FP': 60, 'TN': 18896, 'FN': 7}
# NUM: {'TP': 321, 'FP': 7, 'TN': 19122, 'FN': 66}
# X: {'TP': 14, 'FP': 2, 'TN': 19479, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 645 counts.
# Tag with the most false negative is:  ADJ with 470 counts.
# sentence:       ['Mr.', 'Kennedy', 'had', 'been', 'informed', 'early', 'in', 'the', 'day', 'of', 'the', 'attempt', 'to', 'steal', 'the', 'plane', ',', 'kept', 'in', 'touch', 'throughout', 'by', 'telephone', '.']
# hidden s:       ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'VERB', 'ADP', 'NOUN', 'ADP', 'ADP', 'NOUN', '.']
# DET: {'TP': 2338, 'FP': 245, 'TN': 16929, 'FN': 28}
# NOUN: {'TP': 4695, 'FP': 645, 'TN': 13844, 'FN': 356}
# ADJ: {'TP': 1105, 'FP': 116, 'TN': 17849, 'FN': 470}
# VERB: {'TP': 2436, 'FP': 184, 'TN': 16561, 'FN': 359}
# ADP: {'TP': 2336, 'FP': 231, 'TN': 16881, 'FN': 92}
# .: {'TP': 2391, 'FP': 52, 'TN': 17097, 'FN': 0}
# ADV: {'TP': 677, 'FP': 67, 'TN': 18616, 'FN': 180}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18949, 'FN': 7}
# PRT: {'TP': 437, 'FP': 44, 'TN': 18988, 'FN': 71}
# PRON: {'TP': 553, 'FP': 60, 'TN': 18920, 'FN': 7}
# NUM: {'TP': 321, 'FP': 7, 'TN': 19146, 'FN': 66}
# X: {'TP': 14, 'FP': 2, 'TN': 19503, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 645 counts.
# Tag with the most false negative is:  ADJ with 470 counts.
# sentence:       ['At', 'one', 'time', ',', 'while', 'still', 'under', 'the', 'impression', 'that', 'he', 'was', 'dealing', 'with', 'a', 'Cuban', 'plot', ',', 'the', 'President', 'talked', 'about', 'invoking', 'a', 'total', 'embargo', 'on', 'trade', 'with', 'Cuba', '.']
# hidden s:       ['ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NUM', 'NOUN', '.', 'ADP', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2342, 'FP': 245, 'TN': 16956, 'FN': 28}
# NOUN: {'TP': 4703, 'FP': 646, 'TN': 13866, 'FN': 356}
# ADJ: {'TP': 1105, 'FP': 116, 'TN': 17879, 'FN': 471}
# VERB: {'TP': 2440, 'FP': 184, 'TN': 16588, 'FN': 359}
# ADP: {'TP': 2343, 'FP': 231, 'TN': 16904, 'FN': 93}
# .: {'TP': 2394, 'FP': 52, 'TN': 17125, 'FN': 0}
# ADV: {'TP': 678, 'FP': 68, 'TN': 18645, 'FN': 180}
# CONJ: {'TP': 580, 'FP': 4, 'TN': 18980, 'FN': 7}
# PRT: {'TP': 437, 'FP': 44, 'TN': 19019, 'FN': 71}
# PRON: {'TP': 554, 'FP': 60, 'TN': 18950, 'FN': 7}
# NUM: {'TP': 322, 'FP': 7, 'TN': 19176, 'FN': 66}
# X: {'TP': 14, 'FP': 2, 'TN': 19534, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 646 counts.
# Tag with the most false negative is:  ADJ with 471 counts.
# sentence:       ['As', 'the', 'morning', 'wore', 'on', 'and', 'a', 'blazing', 'West', 'Texas', 'sun', 'wiped', 'the', 'shadows', 'off', 'the', 'Franklin', 'Mountains', ',', 'police', 'got', 'close', 'enough', 'to', 'the', 'plane', 'to', 'pry', 'into', 'the', 'baggage', 'compartment', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'VERB', 'PRT', 'CONJ', 'DET', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'VERB', 'ADP', 'CONJ', 'DET', 'VERB', 'ADJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'NOUN', 'VERB', 'ADV', 'ADV', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2348, 'FP': 245, 'TN': 16983, 'FN': 28}
# NOUN: {'TP': 4713, 'FP': 646, 'TN': 13889, 'FN': 356}
# ADJ: {'TP': 1106, 'FP': 116, 'TN': 17911, 'FN': 471}
# VERB: {'TP': 2445, 'FP': 184, 'TN': 16616, 'FN': 359}
# ADP: {'TP': 2347, 'FP': 232, 'TN': 16932, 'FN': 93}
# .: {'TP': 2396, 'FP': 52, 'TN': 17156, 'FN': 0}
# ADV: {'TP': 680, 'FP': 68, 'TN': 18676, 'FN': 180}
# CONJ: {'TP': 581, 'FP': 4, 'TN': 19012, 'FN': 7}
# PRT: {'TP': 438, 'FP': 44, 'TN': 19050, 'FN': 72}
# PRON: {'TP': 554, 'FP': 60, 'TN': 18983, 'FN': 7}
# NUM: {'TP': 322, 'FP': 7, 'TN': 19209, 'FN': 66}
# X: {'TP': 14, 'FP': 2, 'TN': 19567, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 646 counts.
# Tag with the most false negative is:  ADJ with 471 counts.
# sentence:       ['From', 'the', 'luggage', ',', 'they', 'learned', 'that', 'the', 'two', 'air', 'pirates', ',', 'far', 'from', 'being', 'Cubans', ',', 'were', 'native', 'Americans', ',', 'subsequently', 'identified', 'as', 'Leon', 'Bearden', ',', '50-year-old', 'ex-convict', 'from', 'Coolidge', ',', 'Ariz.', ',', 'and', 'his', 'son', ',', 'Cody', ',', '16', ',', 'a', 'high-school', 'junior', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NUM', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'VERB', 'NOUN', '.', 'VERB', 'NOUN', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'NOUN', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', '.', 'NOUN', '.', 'NUM', '.', 'DET', 'NOUN', 'NOUN', '.']
# DET: {'TP': 2352, 'FP': 246, 'TN': 17024, 'FN': 28}
# NOUN: {'TP': 4727, 'FP': 647, 'TN': 13920, 'FN': 356}
# ADJ: {'TP': 1106, 'FP': 116, 'TN': 17955, 'FN': 473}
# VERB: {'TP': 2449, 'FP': 184, 'TN': 16658, 'FN': 359}
# ADP: {'TP': 2352, 'FP': 232, 'TN': 16973, 'FN': 93}
# .: {'TP': 2407, 'FP': 52, 'TN': 17191, 'FN': 0}
# ADV: {'TP': 681, 'FP': 68, 'TN': 18720, 'FN': 181}
# CONJ: {'TP': 582, 'FP': 4, 'TN': 19057, 'FN': 7}
# PRT: {'TP': 438, 'FP': 44, 'TN': 19096, 'FN': 72}
# PRON: {'TP': 555, 'FP': 61, 'TN': 19027, 'FN': 7}
# NUM: {'TP': 324, 'FP': 7, 'TN': 19253, 'FN': 66}
# X: {'TP': 14, 'FP': 2, 'TN': 19613, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 647 counts.
# Tag with the most false negative is:  ADJ with 473 counts.
# sentence:       ['Tension', 'The', 'heat', 'and', 'strain', 'began', 'to', 'tell', 'on', 'the', 'Beardens', '.']
# hidden s:       ['NOUN', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2354, 'FP': 246, 'TN': 17034, 'FN': 28}
# NOUN: {'TP': 4730, 'FP': 647, 'TN': 13928, 'FN': 357}
# ADJ: {'TP': 1106, 'FP': 116, 'TN': 17967, 'FN': 473}
# VERB: {'TP': 2451, 'FP': 184, 'TN': 16668, 'FN': 359}
# ADP: {'TP': 2353, 'FP': 233, 'TN': 16983, 'FN': 93}
# .: {'TP': 2408, 'FP': 52, 'TN': 17202, 'FN': 0}
# ADV: {'TP': 681, 'FP': 68, 'TN': 18732, 'FN': 181}
# CONJ: {'TP': 583, 'FP': 4, 'TN': 19068, 'FN': 7}
# PRT: {'TP': 439, 'FP': 44, 'TN': 19107, 'FN': 72}
# PRON: {'TP': 555, 'FP': 61, 'TN': 19039, 'FN': 7}
# NUM: {'TP': 324, 'FP': 7, 'TN': 19265, 'FN': 66}
# X: {'TP': 14, 'FP': 2, 'TN': 19625, 'FN': 21}
#
# Tag with the most false positives is: NOUN with 647 counts.
# Tag with the most false negative is:  ADJ with 473 counts.
# sentence:       ['The', 'father', ',', 'by', 'accident', 'or', 'perhaps', 'to', 'show', ',', 'as', 'he', 'said', ',', '``', 'we', 'mean', 'business', "''", ',', 'took', 'the', 'and', 'fired', 'a', 'slug', 'between', 'the', 'legs', 'of', 'Second', 'Officer', 'Norman', 'Simmons', '.']
# hidden s:       ['DET', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'ADV', 'PRT', 'VERB', '.', 'ADP', 'PRON', 'VERB', '.', '.', 'PRON', 'VERB', 'NOUN', '.', '.', 'VERB', 'DET', 'CONJ', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', 'NOUN', '.']
# ...
# DET: {'TP': 2930, 'FP': 316, 'TN': 21572, 'FN': 34}
# NOUN: {'TP': 6051, 'FP': 778, 'TN': 17553, 'FN': 470}
# ADJ: {'TP': 1419, 'FP': 151, 'TN': 22719, 'FN': 563}
# VERB: {'TP': 3113, 'FP': 244, 'TN': 21042, 'FN': 453}
# ADP: {'TP': 3027, 'FP': 289, 'TN': 21420, 'FN': 116}
# .: {'TP': 3060, 'FP': 60, 'TN': 21732, 'FN': 0}
# ADV: {'TP': 846, 'FP': 86, 'TN': 23697, 'FN': 223}
# CONJ: {'TP': 716, 'FP': 5, 'TN': 24124, 'FN': 7}
# PRT: {'TP': 563, 'FP': 55, 'TN': 24143, 'FN': 91}
# PRON: {'TP': 636, 'FP': 85, 'TN': 24120, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24363, 'FN': 83}
# X: {'TP': 14, 'FP': 2, 'TN': 24809, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 778 counts.
# Tag with the most false negative is:  ADJ with 563 counts.
# sentence:       ['We', 'must', 'not', 'permit', 'our', 'society', 'to', 'become', 'a', 'slave', 'to', 'the', 'scientific', 'age', ',', 'as', 'might', 'well', 'happen', 'without', 'the', 'cultural', 'and', 'spiritual', 'restraint', 'that', 'comes', 'from', 'the', 'development', 'of', 'the', 'human', 'mind', 'through', 'wisdom', 'absorbed', 'from', 'the', 'written', 'word', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# DET: {'TP': 2937, 'FP': 316, 'TN': 21606, 'FN': 35}
# NOUN: {'TP': 6059, 'FP': 779, 'TN': 17585, 'FN': 471}
# ADJ: {'TP': 1421, 'FP': 151, 'TN': 22758, 'FN': 564}
# VERB: {'TP': 3121, 'FP': 244, 'TN': 21076, 'FN': 453}
# ADP: {'TP': 3033, 'FP': 289, 'TN': 21455, 'FN': 117}
# .: {'TP': 3062, 'FP': 61, 'TN': 21771, 'FN': 0}
# ADV: {'TP': 848, 'FP': 87, 'TN': 23736, 'FN': 223}
# CONJ: {'TP': 717, 'FP': 5, 'TN': 24165, 'FN': 7}
# PRT: {'TP': 564, 'FP': 55, 'TN': 24184, 'FN': 91}
# PRON: {'TP': 637, 'FP': 86, 'TN': 24160, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24405, 'FN': 83}
# X: {'TP': 14, 'FP': 2, 'TN': 24851, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 779 counts.
# Tag with the most false negative is:  ADJ with 564 counts.
# sentence:       ['A', 'fundamental', 'source', 'of', 'knowledge', 'in', 'the', 'world', 'today', 'is', 'the', 'book', 'found', 'in', 'our', 'libraries', '.']
# hidden s:       ['DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# DET: {'TP': 2941, 'FP': 316, 'TN': 21619, 'FN': 35}
# NOUN: {'TP': 6065, 'FP': 780, 'TN': 17595, 'FN': 471}
# ADJ: {'TP': 1421, 'FP': 151, 'TN': 22774, 'FN': 565}
# VERB: {'TP': 3123, 'FP': 244, 'TN': 21091, 'FN': 453}
# ADP: {'TP': 3036, 'FP': 289, 'TN': 21469, 'FN': 117}
# .: {'TP': 3063, 'FP': 61, 'TN': 21787, 'FN': 0}
# ADV: {'TP': 848, 'FP': 87, 'TN': 23753, 'FN': 223}
# CONJ: {'TP': 717, 'FP': 5, 'TN': 24182, 'FN': 7}
# PRT: {'TP': 564, 'FP': 55, 'TN': 24201, 'FN': 91}
# PRON: {'TP': 637, 'FP': 86, 'TN': 24177, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24422, 'FN': 83}
# X: {'TP': 14, 'FP': 2, 'TN': 24868, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 780 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['Although', 'progress', 'has', 'been', 'made', 'in', "America's", 'system', 'of', 'libraries', 'it', 'still', 'falls', 'short', 'of', 'what', 'is', 'required', 'if', 'we', 'are', 'to', 'maintain', 'the', 'standards', 'that', 'are', 'needed', 'for', 'an', 'informed', 'America', '.']
# hidden s:       ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# DET: {'TP': 2944, 'FP': 316, 'TN': 21649, 'FN': 35}
# NOUN: {'TP': 6071, 'FP': 780, 'TN': 17622, 'FN': 471}
# ADJ: {'TP': 1421, 'FP': 151, 'TN': 22807, 'FN': 565}
# VERB: {'TP': 3134, 'FP': 244, 'TN': 21113, 'FN': 453}
# ADP: {'TP': 3042, 'FP': 289, 'TN': 21496, 'FN': 117}
# .: {'TP': 3064, 'FP': 61, 'TN': 21819, 'FN': 0}
# ADV: {'TP': 850, 'FP': 87, 'TN': 23784, 'FN': 223}
# CONJ: {'TP': 717, 'FP': 5, 'TN': 24215, 'FN': 7}
# PRT: {'TP': 565, 'FP': 55, 'TN': 24233, 'FN': 91}
# PRON: {'TP': 640, 'FP': 86, 'TN': 24207, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24455, 'FN': 83}
# X: {'TP': 14, 'FP': 2, 'TN': 24901, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 780 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['The', 'problem', 'grows', 'in', 'intensity', 'each', 'year', 'as', "man's", 'knowledge', ',', 'and', 'his', 'capacity', 'to', 'translate', 'such', 'knowledge', 'to', 'the', 'written', 'word', ',', 'continue', 'to', 'expand', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# DET: {'TP': 2948, 'FP': 317, 'TN': 21671, 'FN': 35}
# NOUN: {'TP': 6079, 'FP': 781, 'TN': 17640, 'FN': 471}
# ADJ: {'TP': 1422, 'FP': 151, 'TN': 22833, 'FN': 565}
# VERB: {'TP': 3137, 'FP': 244, 'TN': 21135, 'FN': 455}
# ADP: {'TP': 3045, 'FP': 290, 'TN': 21519, 'FN': 117}
# .: {'TP': 3067, 'FP': 61, 'TN': 21843, 'FN': 0}
# ADV: {'TP': 850, 'FP': 87, 'TN': 23811, 'FN': 223}
# CONJ: {'TP': 718, 'FP': 5, 'TN': 24241, 'FN': 7}
# PRT: {'TP': 566, 'FP': 55, 'TN': 24258, 'FN': 92}
# PRON: {'TP': 640, 'FP': 86, 'TN': 24234, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24482, 'FN': 83}
# X: {'TP': 14, 'FP': 2, 'TN': 24928, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 781 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['The', 'inadequacy', 'of', 'our', 'library', 'system', 'will', 'become', 'critical', 'unless', 'we', 'act', 'vigorously', 'to', 'correct', 'this', 'condition', '.']
# hidden s:       ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# DET: {'TP': 2951, 'FP': 317, 'TN': 21686, 'FN': 35}
# NOUN: {'TP': 6083, 'FP': 781, 'TN': 17654, 'FN': 471}
# ADJ: {'TP': 1423, 'FP': 151, 'TN': 22850, 'FN': 565}
# VERB: {'TP': 3141, 'FP': 245, 'TN': 21148, 'FN': 455}
# ADP: {'TP': 3047, 'FP': 290, 'TN': 21535, 'FN': 117}
# .: {'TP': 3068, 'FP': 61, 'TN': 21860, 'FN': 0}
# ADV: {'TP': 850, 'FP': 87, 'TN': 23828, 'FN': 224}
# CONJ: {'TP': 718, 'FP': 5, 'TN': 24259, 'FN': 7}
# PRT: {'TP': 567, 'FP': 55, 'TN': 24275, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24251, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24500, 'FN': 83}
# X: {'TP': 14, 'FP': 2, 'TN': 24946, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 781 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['There', 'are', ',', 'for', 'example', ',', 'approximately', '25,000,000', 'people', 'in', 'this', 'country', 'with', 'no', 'public', 'library', 'service', 'and', 'about', '50,000,000', 'with', 'inadequate', 'service', '.']
# hidden s:       ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'NUM', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'VERB', 'ADP', 'ADJ', 'NOUN', '.']
# DET: {'TP': 2953, 'FP': 317, 'TN': 21708, 'FN': 35}
# NOUN: {'TP': 6089, 'FP': 781, 'TN': 17672, 'FN': 471}
# ADJ: {'TP': 1425, 'FP': 152, 'TN': 22871, 'FN': 565}
# VERB: {'TP': 3142, 'FP': 246, 'TN': 21170, 'FN': 455}
# ADP: {'TP': 3051, 'FP': 290, 'TN': 21555, 'FN': 117}
# .: {'TP': 3071, 'FP': 61, 'TN': 21881, 'FN': 0}
# ADV: {'TP': 852, 'FP': 87, 'TN': 23850, 'FN': 224}
# CONJ: {'TP': 719, 'FP': 5, 'TN': 24282, 'FN': 7}
# PRT: {'TP': 568, 'FP': 55, 'TN': 24298, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24275, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24522, 'FN': 85}
# X: {'TP': 14, 'FP': 2, 'TN': 24970, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 781 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['In', 'college', 'libraries', ',', '57', 'per', 'cent', 'of', 'the', 'total', 'number', 'of', 'books', 'are', 'owned', 'by', '124', 'of', '1,509', 'institutions', 'surveyed', 'last', 'year', 'by', 'the', 'U.S.', 'Office', 'of', 'Education', '.']
# hidden s:       ['ADP', 'NOUN', 'NOUN', '.', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'ADP', 'NUM', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# DET: {'TP': 2955, 'FP': 318, 'TN': 21735, 'FN': 35}
# NOUN: {'TP': 6100, 'FP': 783, 'TN': 17689, 'FN': 471}
# ADJ: {'TP': 1426, 'FP': 152, 'TN': 22900, 'FN': 565}
# VERB: {'TP': 3145, 'FP': 246, 'TN': 21197, 'FN': 455}
# ADP: {'TP': 3059, 'FP': 290, 'TN': 21577, 'FN': 117}
# .: {'TP': 3073, 'FP': 61, 'TN': 21909, 'FN': 0}
# ADV: {'TP': 852, 'FP': 87, 'TN': 23880, 'FN': 224}
# CONJ: {'TP': 719, 'FP': 5, 'TN': 24312, 'FN': 7}
# PRT: {'TP': 568, 'FP': 55, 'TN': 24328, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24305, 'FN': 11}
# NUM: {'TP': 399, 'FP': 7, 'TN': 24549, 'FN': 88}
# X: {'TP': 14, 'FP': 2, 'TN': 25000, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 783 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['And', 'over', '66', 'per', 'cent', 'of', 'the', 'elementary', 'schools', 'with', '150', 'or', 'more', 'pupils', 'do', 'not', 'have', 'any', 'library', 'at', 'all', '.']
# hidden s:       ['CONJ', 'PRT', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# predictions:    ['CONJ', 'PRT', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# DET: {'TP': 2957, 'FP': 318, 'TN': 21755, 'FN': 35}
# NOUN: {'TP': 6104, 'FP': 783, 'TN': 17707, 'FN': 471}
# ADJ: {'TP': 1428, 'FP': 152, 'TN': 22920, 'FN': 565}
# VERB: {'TP': 3147, 'FP': 247, 'TN': 21216, 'FN': 455}
# ADP: {'TP': 3063, 'FP': 290, 'TN': 21595, 'FN': 117}
# .: {'TP': 3074, 'FP': 61, 'TN': 21930, 'FN': 0}
# ADV: {'TP': 853, 'FP': 87, 'TN': 23901, 'FN': 224}
# CONJ: {'TP': 721, 'FP': 5, 'TN': 24332, 'FN': 7}
# PRT: {'TP': 570, 'FP': 55, 'TN': 24348, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24327, 'FN': 11}
# NUM: {'TP': 400, 'FP': 7, 'TN': 24569, 'FN': 89}
# X: {'TP': 14, 'FP': 2, 'TN': 25022, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 783 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['In', 'every', 'aspect', 'of', 'service', '--', 'to', 'the', 'public', ',', 'to', 'children', 'in', 'schools', ',', 'to', 'colleges', 'and', 'universities', '--', 'the', 'library', 'of', 'today', 'is', 'failing', 'to', 'render', 'vitally', 'needed', 'services', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'VERB', 'VERB', 'NOUN', '.']
# DET: {'TP': 2960, 'FP': 318, 'TN': 21784, 'FN': 35}
# NOUN: {'TP': 6114, 'FP': 783, 'TN': 17729, 'FN': 471}
# ADJ: {'TP': 1428, 'FP': 152, 'TN': 22952, 'FN': 565}
# VERB: {'TP': 3151, 'FP': 248, 'TN': 21243, 'FN': 455}
# ADP: {'TP': 3070, 'FP': 290, 'TN': 21620, 'FN': 117}
# .: {'TP': 3079, 'FP': 61, 'TN': 21957, 'FN': 0}
# ADV: {'TP': 853, 'FP': 87, 'TN': 23932, 'FN': 225}
# CONJ: {'TP': 722, 'FP': 5, 'TN': 24363, 'FN': 7}
# PRT: {'TP': 571, 'FP': 55, 'TN': 24379, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24359, 'FN': 11}
# NUM: {'TP': 400, 'FP': 7, 'TN': 24601, 'FN': 89}
# X: {'TP': 14, 'FP': 2, 'TN': 25054, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 783 counts.
# Tag with the most false negative is:  ADJ with 565 counts.
# sentence:       ['Only', 'public', 'understanding', 'and', 'support', 'can', 'provide', 'that', 'service', '.']
# hidden s:       ['ADJ', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', '.']
# DET: {'TP': 2960, 'FP': 318, 'TN': 21793, 'FN': 36}
# NOUN: {'TP': 6117, 'FP': 783, 'TN': 17736, 'FN': 471}
# ADJ: {'TP': 1429, 'FP': 152, 'TN': 22960, 'FN': 566}
# VERB: {'TP': 3153, 'FP': 248, 'TN': 21251, 'FN': 455}
# ADP: {'TP': 3070, 'FP': 291, 'TN': 21629, 'FN': 117}
# .: {'TP': 3080, 'FP': 61, 'TN': 21966, 'FN': 0}
# ADV: {'TP': 853, 'FP': 88, 'TN': 23941, 'FN': 225}
# CONJ: {'TP': 723, 'FP': 5, 'TN': 24372, 'FN': 7}
# PRT: {'TP': 571, 'FP': 55, 'TN': 24389, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24369, 'FN': 11}
# NUM: {'TP': 400, 'FP': 7, 'TN': 24611, 'FN': 89}
# X: {'TP': 14, 'FP': 2, 'TN': 25064, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 783 counts.
# Tag with the most false negative is:  ADJ with 566 counts.
# sentence:       ['This', 'is', 'one', 'of', 'the', 'main', 'reasons', 'for', 'National', 'Library', 'Week', ',', 'April', '16-22', ',', 'and', 'for', 'its', 'theme', ':', '``', 'For', 'a', 'richer', ',', 'fuller', 'life', ',', 'read', "''", '!', '!']
# hidden s:       ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NUM', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'ADJ', '.', 'ADJ', 'NOUN', '.', 'VERB', '.', '.', '.']
# predictions:    ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', '.', 'VERB', '.', '.', '.']
# DET: {'TP': 2964, 'FP': 319, 'TN': 21820, 'FN': 36}
# NOUN: {'TP': 6123, 'FP': 785, 'TN': 17760, 'FN': 471}
# ADJ: {'TP': 1431, 'FP': 152, 'TN': 22988, 'FN': 568}
# VERB: {'TP': 3155, 'FP': 248, 'TN': 21281, 'FN': 455}
# ADP: {'TP': 3074, 'FP': 291, 'TN': 21657, 'FN': 117}
# .: {'TP': 3089, 'FP': 61, 'TN': 21989, 'FN': 0}
# ADV: {'TP': 853, 'FP': 88, 'TN': 23973, 'FN': 225}
# CONJ: {'TP': 724, 'FP': 5, 'TN': 24403, 'FN': 7}
# PRT: {'TP': 571, 'FP': 55, 'TN': 24421, 'FN': 92}
# PRON: {'TP': 641, 'FP': 86, 'TN': 24401, 'FN': 11}
# NUM: {'TP': 401, 'FP': 7, 'TN': 24641, 'FN': 90}
# X: {'TP': 14, 'FP': 2, 'TN': 25096, 'FN': 27}
#
# Tag with the most false positives is: NOUN with 785 counts.
# Tag with the most false negative is:  ADJ with 568 counts.
#
# model got 23040 samples correct out of 25139
# accuracy: 0.9165042364453638

# %% [markdown]
# # comparing HMM(Q2 in HW3) performance to the most frequent tag baseline(Q1 in HW3).
# - HMM tagger: `accuracy: 0.91650`
# - most frequent tag baseline: `accuracy: 0.81841` (assuming all unknown words are 'NN')
# - improved most frequent tag baseline: `accuracy: 0.86276` (using the additional rules for unknown words)

# %% [markdown]
# # Analysis:

# %% [markdown]
# 1. The `collect_probabilities()` function processes the training data and computes the following:
#    - `tag_freq`: The frequency of each tag type observed in the training data.
#    - `word_per_tag_freq`: The frequency of each word observed under each tag in the training data, with initial smoothing.
#    - `bigram`: The transition probabilities between tag types based on bigram counts.
#    - `init_dist`: The initial probability distributions for tag types based on the second tag in each sample.
#
# 2. The `create_confusion_matrix()` function updates the confusion matrices based on the predicted tags and the actual (hidden) tags for each word in the test sentences. It also identifies the tags with the most false positives and false negatives.
#
# 3. The `viterbi()` function implements the Viterbi algorithm for part-of-speech tagging on the test set. It processes each sentence in the test set and performs the following steps:
#    - Initializes the path probability and backpointer dictionaries for the Viterbi algorithm.
#    - Iterates through each word in the sentence, calculating the most likely tag sequence based on the probabilities and transition probabilities.
#    - Determines the best path at the end of the sentence and reconstructs the predicted tag sequence.
#    - Compares the predicted tags with the actual (hidden) tags and updates the confusion matrices accordingly.
#    - Prints the sentence, hidden states, and predicted tags for each sentence, as well as the overall accuracy of the model on the test set.
#
# The key observations from the results are:
#
# - The Viterbi algorithm is implemented to find the most likely sequence of tags for each sentence in the test set.
# - The confusion matrices are used to track the performance of the model, identifying the tags with the most false positives and false negatives.
# - The overall accuracy of the model on the test set is reported, providing a measure of the performance of the HMM-based part-of-speech tagger.
#
# This analysis demonstrates the implementation of a basic HMM-based part-of-speech tagger and the use of the Viterbi algorithm to decode the most likely tag sequence for a given input. The confusion matrices provide valuable insights into the strengths and weaknesses of the model, which can guide further improvements and refinements.
